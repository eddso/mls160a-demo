# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

url_X = 'https://raw.githubusercontent.com/eddso/mls160a-demo/master/data/20200819/xa.csv'
url_Y = 'https://raw.githubusercontent.com/eddso/mls160a-demo/master/data/20200819/ya.csv'
url_Z = 'https://raw.githubusercontent.com/eddso/mls160a-demo/master/data/20200819/za.csv'
url_F = 'https://raw.githubusercontent.com/eddso/mls160a-demo/master/data/20200819/wp.csv'

if True:
  data = pd.read_csv(url_X, header=None)
  npa = np.array(data).T
  x = npa[:][0]
  y = npa[:][1]
  t = [datetime.fromtimestamp(tx/1000) for tx in x]

  # 1.1 Plot the X acceleration data
  fig, ax = plt.subplots(figsize=(20, 6))
  ax = plt.axes()
  ax.set_ylim(-600, 400)
  plt.xlabel('Input Vector Index')
  plt.ylabel('Amplitude')
  ax.set(title="MLS/160 X Acceleration")
  plt.grid(True, axis='both')
  plt.plot(t,y, linestyle='-', color='green')
  plt.gcf().autofmt_xdate()
  plt.show()

if True:
  data = pd.read_csv(url_Y, header=None)
  npa = np.array(data).T
  x = npa[:][0]
  y = npa[:][1]
  t = [datetime.fromtimestamp(tx/1000) for tx in x]

  # 1.1 Plot the X acceleration data
  fig, ax = plt.subplots(figsize=(20, 6))
  ax = plt.axes()
  ax.set_ylim(3600, 4500)
  plt.xlabel('Input Vector Index')
  plt.ylabel('Amplitude')
  ax.set(title="MLS/160 Y Acceleration")
  plt.grid(True, axis='both')
  plt.plot(t,y, linestyle='-', color='red')
  plt.gcf().autofmt_xdate()
  plt.show()

if True:
  data = pd.read_csv(url_Z, header=None)
  npa = np.array(data).T
  x = npa[:][0]
  y = npa[:][1]
  t = [datetime.fromtimestamp(tx/1000) for tx in x]

  # 1.1 Plot the X acceleration data
  fig, ax = plt.subplots(figsize=(20, 6))
  ax = plt.axes()
  ax.set_ylim(-400, 600)
  plt.xlabel('Input Vector Index')
  plt.ylabel('Amplitude')
  ax.set(title="MLS/160 Z Acceleration")
  plt.grid(True, axis='both')
  plt.plot(t,y, linestyle='-', color='blue')
  plt.gcf().autofmt_xdate()
  plt.show()

# %%
if True:
  data = pd.read_csv(url_F, header=None)
  npa = np.array(data).T
  ts = npa[:][0]
  f = npa[:][1]
  m = npa[:][2]
  t = [datetime.fromtimestamp(tx/1000) for tx in ts]

  # 1.1 Plot the X acceleration data
  fig, ax = plt.subplots(figsize=(20, 6))
  ax = plt.axes()
  ax.set_ylim(0, 30000)
  plt.xlabel('Input Vector Index')
  plt.ylabel('Amplitude')
  ax.set(title="MLS/160 X max power Amplitude")
  plt.grid(True, axis='both')
  plt.plot(t,m, linestyle='-', color='blue')
  plt.gcf().autofmt_xdate()
  plt.show()

  # 1.1 Plot the X acceleration data
  fig, ax = plt.subplots(figsize=(20, 6))
  ax = plt.axes()
  ax.set_ylim(0, 300)
  plt.xlabel('Input Vector Index')
  plt.ylabel('Amplitude')
  ax.set(title="MLS/160 max power Frequenz")
  plt.grid(True, axis='both')
  plt.plot(t,f, linestyle='-', color='red')
  plt.gcf().autofmt_xdate()
  plt.show()
